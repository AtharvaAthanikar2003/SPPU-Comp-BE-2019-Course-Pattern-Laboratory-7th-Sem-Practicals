# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
dataset = pd.read_csv('D:/BE Lab Practicals/ML/ML Lab 3/Churn_Modelling.csv', index_col = 'RowNumber')
dataset.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
X_columns = dataset.columns.tolist()[2:12]
Y_columns = dataset.columns.tolist()[-1:]
print(X_columns)
print(Y_columns)
# Out:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
# ['Exited']

# %%
X = dataset[X_columns].values 
Y = dataset[Y_columns].values

# %%
from sklearn.preprocessing import LabelEncoder
X_column_transformer = LabelEncoder()
X[:, 1] = X_column_transformer.fit_transform(X[:, 1])

# %%
X[:, 2] = X_column_transformer.fit_transform(X[:, 2])

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
pipeline = Pipeline(
    [
        ('Categorizer', ColumnTransformer(
            [
                ("Gender Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [2]),
                ("Geography Label Encoder", OneHotEncoder(categories = 'auto', drop = 'first'), [1])
            ], 
            remainder = 'passthrough', n_jobs = 1)),
        ('Normalizer', StandardScaler())
    ]
)

# %%
X = pipeline.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Input

# Initialize the classifier
classifier = Sequential()

# Add input layer and hidden layer
classifier.add(Dense(units=6, activation='relu', input_dim=X_train.shape[1]))
classifier.add(Dropout(rate=0.1))

# %%
#Add second layer
classifier.add(Dense(6, activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# %%
#Add output layer
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
#Let us take a look at our network
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 6)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │              42 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 121 (484.00 B)
#  Trainable params: 121 (484.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#Optimize the weights
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting the Neural Network
history = classifier.fit(X_train, y_train, batch_size = 32, epochs = 200, validation_split = 0.1, verbose = 2)
# Out:
# Epoch 1/200
# 225/225 - 3s - 11ms/step - accuracy: 0.7199 - loss: 0.5777 - val_accuracy: 0.7950 - val_loss: 0.4793
# Epoch 2/200
# 225/225 - 1s - 5ms/step - accuracy: 0.7942 - loss: 0.4837 - val_accuracy: 0.7987 - val_loss: 0.4424
# Epoch 3/200
# 225/225 - 1s - 3ms/step - accuracy: 0.7972 - loss: 0.4600 - val_accuracy: 0.8138 - val_loss: 0.4242
# Epoch 4/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8065 - loss: 0.4448 - val_accuracy: 0.8175 - val_loss: 0.4101
# Epoch 5/200
# 225/225 - 1s - 3ms/step - accuracy: 0.8076 - loss: 0.4352 - val_accuracy: 0.8225 - val_loss: 0.3997
# Epoch 6/200
# 225/225 - 0s - 2ms/step - accuracy: 0.
200
# 225/225 - 1s - 3ms/step - accuracy: 0.8526 - loss: 0.3568 - val_accuracy: 0.8650 - val_loss: 0.3259
# Epoch 144/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8539 - loss: 0.3547 - val_accuracy: 0.8650 - val_loss: 0.3256
# Epoch 145/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8557 - loss: 0.3531 - val_accuracy: 0.8637 - val_loss: 0.3246
# Epoch 146/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8517 - loss: 0.3579 - val_accuracy: 0.8637 - val_loss: 0.3262
# Epoch 147/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8522 - loss: 0.3591 - val_accuracy: 0.8637 - val_loss: 0.3285
# Epoch 148/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8546 - loss: 0.3560 - val_accuracy: 0.8612 - val_loss: 0.3272
# Epoch 149/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8561 - loss: 0.3541 - val_accuracy: 0.8612 - val_loss: 0.3257
# Epoch 150/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8508 - loss: 0.3570 - val_accuracy: 0.8637 - val_loss: 0.3258
# Epoch 151/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8553 - loss: 0.3574 - val_accuracy: 0.8612 - val_loss: 0.3254
# Epoch 152/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8515 - loss: 0.3565 - val_accuracy: 0.8650 - val_loss: 0.3248
# Epoch 153/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8532 - loss: 0.3579 - val_accuracy: 0.8612 - val_loss: 0.3265
# Epoch 154/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8560 - loss: 0.3532 - val_accuracy: 0.8612 - val_loss: 0.3260
# Epoch 155/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8536 - loss: 0.3582 - val_accuracy: 0.8637 - val_loss: 0.3266
# Epoch 156/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8522 - loss: 0.3573 - val_accuracy: 0.8650 - val_loss: 0.3256
# Epoch 157/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8532 - loss: 0.3524 - val_accuracy: 0.8637 - val_loss: 0.3251
# Epoch 158/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8531 - loss: 0.3532 - val_accuracy: 0.8637 - val_loss: 0.3240
# Epoch 159/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8511 - loss: 0.3572 - val_accuracy: 0.8637 - val_loss: 0.3262
# Epoch 160/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8532 - loss: 0.3585 - val_accuracy: 0.8650 - val_loss: 0.3271
# Epoch 161/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8496 - loss: 0.3594 - val_accuracy: 0.8612 - val_loss: 0.3269
# Epoch 162/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8546 - loss: 0.3548 - val_accuracy: 0.8637 - val_loss: 0.3260
# Epoch 163/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8515 - loss: 0.3593 - val_accuracy: 0.8625 - val_loss: 0.3260
# Epoch 164/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8500 - loss: 0.3592 - val_accuracy: 0.8625 - val_loss: 0.3270
# Epoch 165/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8539 - loss: 0.3562 - val_accuracy: 0.8612 - val_loss: 0.3255
# Epoch 166/200
# 225/225 - 1s - 2ms/step - accuracy: 0.8510 - loss: 0.3617 - val_accuracy: 0.8612 - val_loss: 0.3269
# Epoch 167/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8539 - loss: 0.3580 - val_accuracy: 0.8625 - val_loss: 0.3254
# Epoch 168/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8487 - loss: 0.3589 - val_accuracy: 0.8600 - val_loss: 0.3255
# Epoch 169/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8507 - loss: 0.3622 - val_accuracy: 0.8637 - val_loss: 0.3252
# Epoch 170/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8528 - loss: 0.3572 - val_accuracy: 0.8625 - val_loss: 0.3262
# Epoch 171/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8540 - loss: 0.3560 - val_accuracy: 0.8637 - val_loss: 0.3252
# Epoch 172/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8558 - loss: 0.3556 - val_accuracy: 0.8637 - val_loss: 0.3259
# Epoch 173/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8556 - loss: 0.3546 - val_accuracy: 0.8625 - val_loss: 0.3249
# Epoch 174/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8556 - loss: 0.3544 - val_accuracy: 0.8637 - val_loss: 0.3254
# Epoch 175/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8508 - loss: 0.3580 - val_accuracy: 0.8600 - val_loss: 0.3277
# Epoch 176/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8558 - loss: 0.3535 - val_accuracy: 0.8625 - val_loss: 0.3258
# Epoch 177/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8549 - loss: 0.3528 - val_accuracy: 0.8612 - val_loss: 0.3260
# Epoch 178/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8501 - loss: 0.3554 - val_accuracy: 0.8612 - val_loss: 0.3256
# Epoch 179/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8537 - loss: 0.3555 - val_accuracy: 0.8625 - val_loss: 0.3252
# Epoch 180/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8512 - loss: 0.3581 - val_accuracy: 0.8650 - val_loss: 0.3252
# Epoch 181/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8554 - loss: 0.3588 - val_accuracy: 0.8612 - val_loss: 0.3270
# Epoch 182/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8506 - loss: 0.3593 - val_accuracy: 0.8625 - val_loss: 0.3266
# Epoch 183/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8546 - loss: 0.3585 - val_accuracy: 0.8587 - val_loss: 0.3273
# Epoch 184/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8549 - loss: 0.3560 - val_accuracy: 0.8612 - val_loss: 0.3266
# Epoch 185/200
# 225/225 - 1s - 3ms/step - accuracy: 0.8515 - loss: 0.3563 - val_accuracy: 0.8625 - val_loss: 0.3253
# Epoch 186/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8564 - loss: 0.3561 - val_accuracy: 0.8675 - val_loss: 0.3237
# Epoch 187/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8533 - loss: 0.3569 - val_accuracy: 0.8625 - val_loss: 0.3251
# Epoch 188/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8546 - loss: 0.3530 - val_accuracy: 0.8612 - val_loss: 0.3258
# Epoch 189/200
# 225/225 - 1s - 2ms/step - accuracy: 0.8522 - loss: 0.3538 - val_accuracy: 0.8625 - val_loss: 0.3245
# Epoch 190/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8529 - loss: 0.3517 - val_accuracy: 0.8625 - val_loss: 0.3250
# Epoch 191/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8542 - loss: 0.3530 - val_accuracy: 0.8625 - val_loss: 0.3249
# Epoch 192/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8546 - loss: 0.3513 - val_accuracy: 0.8575 - val_loss: 0.3251
# Epoch 193/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8525 - loss: 0.3546 - val_accuracy: 0.8625 - val_loss: 0.3248
# Epoch 194/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8544 - loss: 0.3590 - val_accuracy: 0.8637 - val_loss: 0.3265
# Epoch 195/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8496 - loss: 0.3599 - val_accuracy: 0.8625 - val_loss: 0.3266
# Epoch 196/200
# 225/225 - 1s - 2ms/step - accuracy: 0.8517 - loss: 0.3570 - val_accuracy: 0.8625 - val_loss: 0.3290
# Epoch 197/200
# 225/225 - 1s - 3ms/step - accuracy: 0.8533 - loss: 0.3570 - val_accuracy: 0.8637 - val_loss: 0.3277
# Epoch 198/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8542 - loss: 0.3532 - val_accuracy: 0.8612 - val_loss: 0.3251
# Epoch 199/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8557 - loss: 0.3564 - val_accuracy: 0.8625 - val_loss: 0.3262
# Epoch 200/200
# 225/225 - 0s - 2ms/step - accuracy: 0.8553 - loss: 0.3558 - val_accuracy: 0.8637 - val_loss: 0.3274

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[0.26894277]
#  [0.31418166]
#  [0.16971996]
#  [0.05702815]
#  [0.09412862]]

# %%
#Let us use confusion matrix with cutoff value as 0.5
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
#Making the Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1556   39]
#  [ 235  170]]

# %%
#Accuracy of our NN
print(((cm[0][0] + cm[1][1])* 100) / len(y_test), '% of data was classified correctly')
# Out:
# 86.3 % of data was classified correctly
